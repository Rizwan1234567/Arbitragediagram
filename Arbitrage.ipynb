# %%
import requests

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
api_data=requests.get("https://api.cryptonator.com/api/full/btc-usd").json()

# %%
mkt_data=api_data["ticker"]["markets"]

# %%
df=pd.DataFrame(mkt_data)
markets=df["market"]

# %%
print(df)
# Out:
#       market          price        volume
# 0   BitFinex  6706.00000000  56016.297814
# 1   Bitstamp  6699.01000000  10925.523334
# 2    Bittrex  6700.00000000   2768.359615
# 3      C-Cex  7004.00000000      3.149008
# 4     Cex.io  6860.80000000    869.060731
# 5       Exmo  6969.76000000   1067.677655
# 6     Hitbtc  7019.78000000   6151.970000
# 7     Kraken  6675.00000000   7380.167040
# 8   Livecoin  7068.47640000   1557.967860
# 9   Poloniex  6693.12890330   2579.680233
# 10     wexnz  6928.95500000    939.638850
# 11     YoBit  7150.00000000    147.196350

# %%
price = df["price"]

# %%
np_price=np.array(price)

# %%
volume = df["volume"]

# %%
np_volume=np.array(volume)

# %%
max_price=np.max(np_price)

# %%
min_price=np.min(np_price)

# %%
max_mkt = np.argmax(np_price)

# %%
min_mkt = np.argmin(np_price)

# %%
print(markets[max_mkt])
# Out:
# C-Cex

# %%
difference = float(max_price)-float(min_price)

# %%
print("market", markets[max_mkt], "has max price" +str(max_price))
# Out:
# market C-Cex has max price7429.00000000

# %%
print("market", markets[min_mkt], "has min price" +str(min_price))
# Out:
# market Kraken has min price6673.40000000

# %%
print("differnce in price is: ", difference)
# Out:
# differnce in price is:  755.6000000000004

# %%
plt.figure(figsize=(20,10))
plt.scatter(price,volume)
plt.ylabel("volume")
plt.ylabel("price")
for i in (markets.index):
    plt.annotate(markets[i],xy=(price[i],volume[i]),xytext=(price[i],volume[i]))

# %%
# Out:
# array(25)
